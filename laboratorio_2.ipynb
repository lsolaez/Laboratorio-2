# %%
# Importando algunas librerías que utilizaremos

# Networkx para grafos
import networkx as nx
import sys
# Pandas
import pandas as pd

# Mostrar imágenes
from IPython.display import HTML

# Mathplotlib
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (20.0, 10.0)

# %%
#Funcion para mostrar el camino
def show_path(path):
    #Variables contadoras para mostrar precio del vuelo y la duracion
    total_price = 0
    total_duration = 0
    #Iteramos de acuerdo a lo largo que sea el camino
    for i in range(len(path)-1):
        origin = path[i]
        destination = path[i+1]
        duration = DG[origin][destination]["duration"]
        price = DG[origin][destination]["price"]
        
        total_price = total_price+price
        total_duration = total_duration+duration
        print("    %s -> %s\n    - Duration: %s Price: %s $" % (
            Aeropuertos.loc[origin]["name"],
            Aeropuertos.loc[destination]["name"],
            duration, price)
        )
    
    print("\n     Total Duration: %s Total price: %s $ \n" % (
            total_duration, total_price)
    )
#Encuentra todos los caminos mas cortos
def get_all_shortest_paths(DiGraph, origin, destination):
    print("*** All shortest paths - Origen: %s Destino: %s" % (
        origin, destination
    ))
    for weight in [None, "duration", "price"]:
        print("* Ordenando por: %s" % weight)
        paths = list(nx.all_shortest_paths(DiGraph,
                                          source=origin,
                                          target=destination,
                                          weight=weight))
        for path in paths:
            print("   Camino óptimo: %s" % path)
            show_path(path)
    
#Encuentra todos los caminos mas cortos
def get_all_shortest_paths(DiGraph, origin, destination):
    print("*** All shortest paths - Origen: %s Destino: %s" % (
        origin, destination
    ))
    for weight in [None, "duration", "price"]:
        print("* Ordenando por: %s" % weight)
        paths = list(nx.all_shortest_paths(DiGraph,
                                          source=origin,
                                          target=destination,
                                          weight=weight))
        for path in paths:
            print("   Camino óptimo: %s" % path)
            show_path(path)
#Dibuja el camino sobre el grafo
def plot_shortest_path(path):
    print(path)
    positions = nx.circular_layout(DG)
    
    nx.draw(DG, pos=positions,
                node_color='lightblue',
                edge_color='gray',
                font_size=24,
                width=1, with_labels=True, node_size=3500, alpha=0.8
           )
    
    short_path=nx.DiGraph()
    for i in range(len(path)-1):
        short_path.add_edge(path[i], path[i+1])
    
    nx.draw(short_path, pos=positions,
                node_color='dodgerblue',
                edge_color='dodgerblue',
                font_size=24,
                width=3, with_labels=True, node_size=3000
           )
    plt.show()
        
def get_shortest_path(DiGraph, origin, destination):
    print("*** Origen: %s Destino: %s" % (origin, destination))
    
    for weight in [None, "duration", "price"]:
        print(" Ordenado por: %s" % weight)
        path = list(nx.astar_path(DiGraph,
                                  (origin),
                                  (destination),
                                  weight=weight
                                 ))
        print("   Camino óptimo: %s " % path)
        show_path(path)
        plot_shortest_path(path)

 
#Abriendo el archivo donde tenemos el dataset de los aeropuertos
Aeropuertos = pd.read_csv('Aeropuertos.csv')
#Haciendo que el indice sea la columna code
Aeropuertos.set_index(["code"], inplace=True)
#Obteniendo el dataframe de vuelos
vuelos = pd.read_csv("vuelos.csv")
#Creando un grafo dirigido
DG=nx.DiGraph()
for row in vuelos.iterrows():
    DG.add_edge(row[1]["origin"],
                row[1]["destination"],
                duration=row[1]["duration"],
                price=row[1]["price"])



while True:
    print("---- Menú ----")
    print("1. Buscar aeropuerto")
    print("2. Buscar vuelo")
    print("3. DFS")
    print("4. BFS")
    print("5. Salir")
    
    opcion = input("Ingrese una opción: ")
    
    if opcion == "1":
        code = input('Ingrese el código IATA del aeropuerto a buscar: ')
        print(Aeropuertos.loc[code])
        
    elif opcion == "2":
        origen = input("Ingrese el origen del vuelo en código IATA: ")
        if origen not in DG.nodes:
            print("El origen no se encuentra en el grafo. Inténtelo de nuevo.")
            continue

        destino = input("Ingrese el destino del vuelo en código IATA: ")
        if destino not in DG.nodes:
            print("El destino no se encuentra en el grafo. Inténtelo de nuevo.")
            continue

        try:
            get_shortest_path(DG, origen, destino)
        except nx.exception.NetworkXNoPath:
            print("No existe un camino entre los nodos de origen y destino.")

    elif opcion == "3":
        origen=input('Ingrese el nodo origen para el DFS: ')
        try:
          dfs_nodes = list(nx.dfs_preorder_nodes(DG, source=origen))
          # Imprime los nodos visitados en el recorrido DFS
          for node in dfs_nodes:
              print(Aeropuertos.loc[node])
        except KeyError:
            print("El nodo ingresado no se encuentra en el grafo.")
    elif opcion == "4":
        origen=input('Ingrese el nodo origen para el DFS: ')
        try:
          bfs_nodes = list(nx.bfs_tree(DG, source=origen))
          # Imprime los nodos visitados en el recorrido DFS
          for node in bfs_nodes:
              print(Aeropuertos.loc[node])
        except KeyError:
            print("El nodo ingresado no se encuentra en el grafo.")
    elif opcion == "5":
        print("¡Hasta luego!")
        break
        
    else:
        print("Opción inválida. Inténtelo de nuevo.")
# Out:
# ---- Menú ----
# 1. Buscar aeropuerto
# 2. Buscar vuelo
# 3. DFS
# 4. BFS
# 5. Salir
# Ingrese una opción: 4
# Ingrese el nodo origen para el DFS: MEX
# localizate                          Mexico DF-Mexico
# name          Aeropuerto Internacional Benito Juarez
# Name: MEX, dtype: object
# localizate        Washington D.C-Estados Unidos
# name          Aeropuerto Nacional Ronald Reagan
# Name: DCA, dtype: object
# localizate                       Bogota-Colombia
# name          Aeropuerto Internacional El Dorado
# Name: BOG, dtype: object
# localizate         Ciudad de Guatemala-Guatemala
# name          Aeropuerto Internacional La Aurora
# Name: GUA, dtype: object
# localizate                  Tegucipalca-Honduras
# name          Aeropuerto Internacional Toncontin
# Name: TGU, dtype: object
# localizate                          Managua - Nicaragua
# name          Aeropuerto Internacional Augusto C.Sandin
# Name: MGA, dtype: object
# localizate                                    Ottawa-Canada
# name          Ottawa McDonald-Cartier International Airport
# Name: YOW, dtype: object
# localizate                              Quito-Ecuador
# name          Aeropuerto Internacional Mariscal Sucre
# Name: UIO, dtype: object
# localizate                                    Caracas-Venezuela
# name          Aeropuerto Internacional de Maiquetia Simon Bo...
# Name: CCS, dtype: object
# localizate                                Lima-Peru
# name          Aeropuerto Internacional Jorge Chavez
# Name: LIM, dtype: object
# localizate                         Buenos Aires-Argentina
# name          Aeropuerto Internacional Ministro Pistarini
# Name: EZE, dtype: object
# localizate                          Panama-Panama
# name          Aeropuerto Internacional de Tocumen
# Name: PTY, dtype: object
# localizate                     Montevideo -Uruguay
# name          Aeropuerto Internacional de Carrasco
# Name: MVD, dtype: object
# localizate                   San Salvador-El Salvador
# name          Aeropuerto Internacional de El Salvador
# Name: SAL, dtype: object
# localizate                            Sucre-Bolivia
# name          Aeropuerto Internacional de Alcantara
# Name: SER, dtype: object
# localizate                        Brasilia-Brasil
# name          Aeropurto Internacional de Brasilia
# Name: BSB, dtype: object
# El nodo ingresado no se encuentra en el grafo.
# ---- Menú ----
# 1. Buscar aeropuerto
# 2. Buscar vuelo
# 3. DFS
# 4. BFS
# 5. Salir
# Ingrese una opción: 5
# ¡Hasta luego!
